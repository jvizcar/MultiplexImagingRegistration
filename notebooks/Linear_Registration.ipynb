# %% [markdown]
# # Linear Registration
# Updated - 6 Nov. 2020
#
# Rerun linear registration as performed in the hackathon and plot results alongside the hackathon results.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('..')

from mpleximreg import utils, registration
import seaborn as sns
from pandas import read_csv
import matplotlib.pyplot as plt
from imageio import imwrite, imread
from tifffile import imsave

# %% [markdown]
# ## Linear registration on single images

# %%
raw_tif_dir = '/data/breastCancer/'
raw_tif_dict = utils.parse_tif_dir(raw_tif_dir)

transformer, target_shape = registration.rigid_transformer(raw_tif_dict[2][1], raw_tif_dict[1][1])
im = registration.rigid_transform(raw_tif_dict[2][1], transformer, target_shape, 'jc.tif')

# %% [markdown]
# ## Linear registration on image tif directories

# %%
imsave('test.tif', im)

# %%
from skimage.io import imsave

imsave('skimageio.tif', im, plugin="tifffile")

# %%
jc = imread('test.tif')
plt.imshow(jc)

# %%
registration.rigid_transform_dir(raw_tif_dir, 'JC')
